# %%
import matplotlib.pyplot as pyplot

# %%
labels= ('python', 'java', 'scala', 'c#')
sizes = [45, 30, 15, 10]
pyplot.pie(sizes,
         labels=labels,
         autopct = '%1.f%%',
         counterclock=False,
         startangle=105)
# Display Figure
pyplot.show()
